# %% [markdown]
# <a href="https://colab.research.google.com/github/Sammy-Sasaki/SammyAIT23/blob/main/Assessment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://a.espncdn.com/i/headshots/nba/players/full/3202.png
# Out:
# --2023-02-14 14:53:31--  https://a.espncdn.com/i/headshots/nba/players/full/3202.png
# Resolving a.espncdn.com (a.espncdn.com)... 23.221.227.171, 23.221.227.174, 2600:1408:c400:68::17db:9a49, ...
# Connecting to a.espncdn.com (a.espncdn.com)|23.221.227.171|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 265686 (259K) [image/png]
# Saving to: ‘3202.png’
#
# 3202.png            100%[===================>] 259.46K  --.-KB/s    in 0.004s
#
# 2023-02-14 14:53:31 (66.7 MB/s) - ‘3202.png’ saved [265686/265686]

# %%
from PIL import Image
  
# open method used to open different extension image file
im = Image.open("3202.png")
im
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=600x436 at 0x7F7FBC065DF0>

# %%
im.size
# Out:
# (600, 436)

# %%
data = im.load()
for i in range(570,600):
  for j in range(30):
    data[i,j] = (0,0,0)
im
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=600x436 at 0x7F7FBC065DF0>
